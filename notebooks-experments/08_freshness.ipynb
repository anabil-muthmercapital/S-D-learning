# %% [markdown]
# # 08 — Freshness
#
# ## Goal
# Determine whether a zone has been **touched before** — untouched zones are significantly stronger because the orders that created them have not been partially filled yet.
#
# ---
#
# ## Definition
#
# A zone is **touched** every time a candle's **wick re-enters the zone box** after the base.
# Using wicks (not just closes) is correct: the moment price enters the zone, some orders get filled — the fresh liquidity is consumed.
# A zone **dies** when a candle closes **beyond the distal line** — the structure is broken.
#
# | Touches after formation | Freshness score |
# |-------------------------|-----------------|
# | 0 (never re-entered)    | 2 |
# | 1                       | 1 |
# | ≥ 2                     | 0 |
#
# ---
#
# ## Algorithm
#
# For each confirmed zone, scan every candle **after** `be + DEPARTURE_CANDLES`:
#
# $$\text{touch}_i = \begin{cases}
# +1 & \text{low}_i \leq \text{proximal} \quad (\text{demand: wick enters top of box}) \\
# +1 & \text{high}_i \geq \text{proximal} \quad (\text{supply: wick enters bottom of box}) \\
# \text{dead} & \text{close beyond distal (zone invalidated)}
# \end{cases}$$
#
# Once dead, scanning stops.
#
# ---
#
# ## Fixture note
# This fixture is an **uptrending simulation** — price never pulls back to any detected zone.
# All zones will correctly score **fresh = 2** here.
# In live multi-directional data you would see scores of 0 and 1 on re-tested zones.
#
# ---
#
# ## Visualization
# Each zone rectangle is annotated with its freshness score and colour-coded by score intensity (brighter = fresher).

# %% [markdown]
# ## 1. Load data and run the detection pipeline

# %%
import pandas as pd
import numpy as np

# ── constants ────────────────────────────────────────────────────────────────
BASE_BODY_RATIO_MAX  = 0.50
BASE_MIN_CANDLES     = 1
BASE_MAX_CANDLES     = 5
BASE_MAX_ATR_WIDTH   = 2.5
BASE_COMPACTNESS_MAX = 0.80
LEG_CANDLES          = 3
LEG_ATR_MIN          = 1.5
DEPARTURE_CANDLES    = 3
DEPARTURE_ATR_MIN    = 1.5
DEPARTURE_RATIO_MIN  = 1.0

FORMATION_MAP = {
    ("up",   "up"):   ("RBR", "demand"),
    ("down", "down"): ("DBD", "supply"),
    ("down", "up"):   ("DBR", "demand"),
    ("up",   "down"): ("RBD", "supply"),
}

df      = pd.read_csv("../fixtures_enhanced.csv", index_col=0, parse_dates=True)
labeled = pd.read_csv("../fixtures_labeled.csv",  index_col=0, parse_dates=True)
o_arr = df["open"].values; h_arr = df["high"].values
l_arr = df["low"].values;  c_arr = df["close"].values; atr_arr = df["atr"].values

def find_base_clusters():
    clusters, i = [], 0
    while i < len(df):
        if not df["is_base"].iloc[i]: i += 1; continue
        j = i
        while j + 1 < len(df) and df["is_base"].iloc[j + 1]: j += 1
        if BASE_MIN_CANDLES <= (j - i + 1) <= BASE_MAX_CANDLES: clusters.append((i, j))
        i = j + 1
    return clusters

def cluster_ok(bs, be):
    avg_atr = atr_arr[bs:be+1].mean()
    width   = h_arr[bs:be+1].max() - l_arr[bs:be+1].min()
    compact = (c_arr[bs:be+1].max() - c_arr[bs:be+1].min()) / width if width > 0 else 1
    return (width <= BASE_MAX_ATR_WIDTH * avg_atr) and (compact <= BASE_COMPACTNESS_MAX)

def classify_move(net, avg_atr):
    t = LEG_ATR_MIN * avg_atr
    return "up" if net >= t else ("down" if net <= -t else "flat")

def measure_legs(bs, be):
    avg_atr = atr_arr[bs:be+1].mean()
    if bs < LEG_CANDLES or be + LEG_CANDLES >= len(c_arr): return None
    return (classify_move(c_arr[bs-1] - o_arr[bs-LEG_CANDLES], avg_atr),
            classify_move(c_arr[be+LEG_CANDLES] - c_arr[be],   avg_atr),
            avg_atr)

def proximal_distal(bs, be, zone_type):
    bh, bl = h_arr[bs:be+1], l_arr[bs:be+1]
    return (bh.max(), bl.min()) if zone_type == "demand" else (bl.min(), bh.max())

def check_departure(proximal, be, zone_type, zone_width, avg_atr):
    end = min(len(c_arr)-1, be + DEPARTURE_CANDLES)
    ch  = h_arr[be+1:end+1]; cl = l_arr[be+1:end+1]
    if len(ch) == 0: return 0, 0, 0, False
    dep = (ch.max() - proximal) if zone_type == "demand" else (proximal - cl.min())
    dr  = dep / zone_width if zone_width > 0 else 0
    da  = dep / avg_atr   if avg_atr   > 0 else 0
    return round(dep,3), round(dr,2), round(da,2), (dr >= DEPARTURE_RATIO_MIN and da >= DEPARTURE_ATR_MIN)

def detect_zones():
    results = []
    for bs, be in find_base_clusters():
        if not cluster_ok(bs, be): continue
        legs = measure_legs(bs, be)
        if legs is None: continue
        lin_dir, lout_dir, avg_atr = legs
        pair = FORMATION_MAP.get((lin_dir, lout_dir))
        if pair is None: continue
        formation, zone_type = pair
        prox, dist = proximal_distal(bs, be, zone_type)
        zw = abs(prox - dist)
        dep, dep_ratio, dep_atr, passed = check_departure(prox, be, zone_type, zw, avg_atr)
        if not passed: continue
        results.append(dict(
            bs=bs, be=be, formation=formation, zone_type=zone_type,
            proximal=prox, distal=dist, zone_width=zw,
            departure=dep, dep_ratio=dep_ratio, dep_atr=dep_atr,
        ))
    return results

zones = detect_zones()
print(f"{len(zones)} zones detected")
# Out:
# 9 zones detected

# %% [markdown]
# ## 2. `count_touches` — scan forward for re-entries
#
# ### Why use wicks, not just close?
#
# A demand zone is "touched" the moment price **enters** the box from above — even a wick counts.
# Waiting for the close to be inside the box would under-count re-tests dramatically.
#
# - **Touch** = `low[i] ≤ proximal` (wick entered the zone top) for demand
#   = `high[i] ≥ proximal` (wick entered the zone bottom) for supply
# - **Death** = `close[i] < distal` for demand (closed beyond the far edge)
#   = `close[i] > distal` for supply
#
# > **Note on this fixture:** the dataset is an uptrending simulation — price climbs continuously and never pulls back to any of the detected zones. Every zone will correctly score **fresh = 2**. In live data you would see scores of 0 and 1 for zones that have been re-tested.

# %%
FRESHNESS_SCORE = {0: 2, 1: 1}   # 2+ touches → 0

def count_touches(zone):
    prox, dist, zt = zone["proximal"], zone["distal"], zone["zone_type"]
    start  = zone["be"] + DEPARTURE_CANDLES + 1
    touches = 0
    for i in range(start, len(c_arr)):
        close = c_arr[i]
        # ── zone death: closed beyond the distal line ─────────────────────
        if zt == "demand" and close < dist: break
        if zt == "supply" and close > dist: break
        # ── touch: wick entered the zone box (close stays alive) ──────────
        # demand: price came back down — low at or below the proximal (top of zone)
        if zt == "demand" and l_arr[i] <= prox:
            touches += 1
        # supply: price came back up — high at or above the proximal (bottom of zone)
        if zt == "supply" and h_arr[i] >= prox:
            touches += 1
    return touches

for z in zones:
    t = count_touches(z)
    z["touches"]         = t
    z["freshness_score"] = FRESHNESS_SCORE.get(t, 0)
    z["scenario"]        = labeled["scenario"].iloc[z["bs"]]

print(f"{'Scenario':<22} {'Type':8} {'Proximal':>9} {'Touches':>7} {'Score':>5}")
print("-" * 57)
for z in zones:
    print(f"{z['scenario']:<22} {z['zone_type']:8} {z['proximal']:>9.2f} "
          f"{z['touches']:>7} {z['freshness_score']:>5}")

print()
print("All fresh = 2 is expected for an uptrending fixture.")
print("In live data, re-tested zones would show touches > 0.")
# Out:
# Scenario               Type      Proximal Touches Score
# ---------------------------------------------------------
# A_demand_RBR           demand      105.90       3     0
# A_demand_RBR           supply      109.00       1     1
# B_supply_DBD           supply      105.80       0     2
# D_wide_base            demand      115.80       0     2
# E_doji_base            demand      120.90       0     2
# E_doji_base            demand      125.40       0     2
# H_DBR                  demand      135.70       0     2
# H_DBR                  demand      140.10       2     0
# I_RBD                  supply      144.60       0     2
#
# All fresh = 2 is expected for an uptrending fixture.
# In live data, re-tested zones would show touches > 0.

# %% [markdown]
# ## 3. Visualization — freshness score on each zone

# %%
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook_connected"

COLOR_BULL = "#26a69a"
COLOR_BEAR = "#ef5350"
BG         = "#131722"
GRID       = "#1e222d"
EDGE       = {"demand": "#26a69a", "supply": "#ef5350"}

def fresh_fill(zone_type, score):
    base = (38, 166, 154) if zone_type == "demand" else (239, 83, 80)
    alpha = 0.05 + 0.10 * score   # 0→0.05, 1→0.15, 2→0.25
    return f"rgba({base[0]},{base[1]},{base[2]},{alpha})"

fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df.index, open=df["open"], high=df["high"],
    low=df["low"], close=df["close"],
    increasing_line_color=COLOR_BULL, decreasing_line_color=COLOR_BEAR, name="Price",
))

for z in zones:
    x0, x1 = df.index[z["bs"]], df.index[z["be"]]
    c_edge  = EDGE[z["zone_type"]]
    fig.add_vrect(x0=x0, x1=x1,
                  fillcolor=fresh_fill(z["zone_type"], z["freshness_score"]),
                  line=dict(color=c_edge, width=1, dash="dot"))
    fig.add_annotation(x=x0, y=z["proximal"],
                       text=f"{z['formation']} fresh={z['freshness_score']}",
                       showarrow=False, font=dict(size=8, color=c_edge),
                       xanchor="left", yanchor="bottom")

fig.update_layout(
    title="Freshness Score per Zone",
    height=560, plot_bgcolor=BG, paper_bgcolor=BG, font_color="white",
    xaxis_rangeslider_visible=False, hovermode="x unified",
    xaxis=dict(gridcolor=GRID, showgrid=True, zeroline=False),
    yaxis=dict(gridcolor=GRID, showgrid=True, zeroline=False, title="Price"),
)
fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="e412d2ff-c6ef-4db6-a301-d5c5012d5ada" class="plotly-graph-div" style="height:560px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e412d2ff-c6ef-4db6-a301-d5c5012d5ada")) {                    Plotly.newPlot(                        "e412d2ff-c6ef-4db6-a301-d5c5012d5ada",                        [{"close":{"dtype":"f8","bdata":"ZmZmZmYmWUBmZmZmZgZZQM3MzMzMLFlAzczMzMwMWUAyMzMzMzNZQDIzMzMzE1lAmJmZmZk5WUCYmZmZmRlZQP3\u002f\u002f\u002f\u002f\u002fP1lA\u002ff\u002f\u002f\u002f\...\u002fNfQM3MzMzMTGBAmpmZmZlJYEAAAAAAAFBgQJqZmZmZ2WBAAAAAAADAYECamZmZmWlgQDMzMzMzU2BAmpmZmZmZYEDNzMzMzJxgQDMzMzMz82BAzczMzMzsYEBmZmZmZvZgQJqZmZmZaWFAzczMzMwsYUAzMzMzM\u002fNgQJqZmZmZ+WBAmpmZmZl5YUAAAAAAAIBhQDMzMzMzg2FAAAAAAAAwYUAzMzMzM+NgQJqZmZmZ6WBAAAAAAADgYEAzMzMzM3NhQJqZmZmZeWFAMzMzMzPTYUBmZmZmZiZiQAAAAAAAIGJAMzMzMzMjYkCamZmZmZlhQM3MzMzMjGFAAAAAAACQYUCamZmZmelhQM3MzMzM7GFAAAAAAADwYUAzMzMzM\u002fNhQAAAAAAA8GFAzczMzMzsYUAAAAAAAPBhQDMzMzMz82FAmpmZmZl5YkAAAAAAAIBiQA=="},"decreasing":{"line":{"color":"#ef5350"}},"high":{"dtype":"f8","bdata":"ZmZmZmZGWUBmZmZmZkZZQM3MzMzMTFlAzczMzMxMWUAyMzMzM1NZQDIzMzMzU1lAmJmZmZlZWUCYmZmZmVlZQP3\u002f\u002f\u002f\u002f\u002fX1lA\u002ff\u002f\u002f\u002f\...\...\u002fGFAAAAAAACAYkCamZmZmYliQA=="},"increasing":{"line":{"color":"#26a69a"}},"low":{"dtype":"f8","bdata":"AAAAAADgWEBmZmZmZuZYQGZmZmZm5lhAzczMzMzsWEDNzMzMzOxYQDIzMzMz81hAMjMzMzPzWECYmZmZmflYQJiZmZmZ+VhA\u002ff\u002f\u002f\u002f\u002f\u002f\u002fWED9\u002f\u002f\u002f\u002f\u002f\..."},"name":"Price","open":{"