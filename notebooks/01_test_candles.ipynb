# %%
# %pip install pandas numpy plotly nbformat pydantic --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
from sd_core.candle import body_ratio , true_range , average_true_range
from sd_core.zone import compactness

# %%
TICKER_NAME = "USDJPY=X"
TICKER_TF = "1h"

df = pd.read_csv(f"../data/raw/{TICKER_NAME}/{TICKER_TF}.csv" , parse_dates=["Datetime"], index_col="Datetime")
df["body_ratio"] = body_ratio(df)
df["true_range"] = true_range(df)
df["average_true_range"] = average_true_range(df)
df["compactness_passed"] = compactness(df)
df.tail(60)
# Out:
#                                  open        high         low       close  \
# Datetime
# 2026-06-03 09:00:00+00:00  159.748001  159.884003  159.746002  159.789001
# 2026-06-03 10:00:00+00:00  159.779999  159.854996  159.656998  159.785995
# 2026-06-03 11:00:00+00:00  159.791000  159.839996  159.774994  159.837997
# 2026-06-03 12:00:00+00:00  159.834000  159.931000  159.772995  159.910995
# 2026-06-03 13:00:00+00:00  159.910995  159.985001  159.886993  159.951996
# 2026-06-03 14:00:00+00:00  159.973999  160.001999  159.891006  159.940002
# 2026-06-03 15:00:00+00:00  159.940002  160.005005  159.932007  159.970993
# 2026-06-03 16:00:00+00:00  159.962997  160.048996  159.942993  159.983002
# 2026-06-03 17:00:00+00:00  159.977997  160.050995  159.945999  160.037994
# 2026-06-03 18:00:00+00:00  160.048996  160.059998  160.011002  160.033005
# 2026-06-03 19:00:00+00:00  160.031998  160.080002  159.994003  160.070999
# ...
